# %% [markdown]
# Visualize the data using R/Python by plotting the graphs for assignment no. 1 and 2. Consider suitable data set. a) Use Scatter plot, bar plot, Box plot and Histogram

# %%
#c

# %%
ds=pd.read_csv("/content/car_crashes.csv")
df=pd.read_csv("/content/admission.csv")

# %%
ds.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
sns.scatterplot(ds, y="alcohol", x="speeding" , hue ="total" )
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
sns.barplot(df,x="University Rating",y="TOEFL Score")
# Out:
# <Axes: xlabel='University Rating', ylabel='TOEFL Score'>

# %%
sns.histplot(df, x="GRE Score")
# Out:
# <Axes: xlabel='GRE Score', ylabel='Count'>

# %%
sns.boxplot(df,x="University Rating", y="SOP")
# Out:
# <Axes: xlabel='University Rating', ylabel='SOP'>

# %%
sns.pairplot(ds)

# %%
ds = ds.drop(["abbrev"], axis=1)

# %%
corr = ds.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
sns.displot(df, x="University Rating", y="CGPA")
